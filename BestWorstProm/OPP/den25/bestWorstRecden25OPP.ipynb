# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def printImgs(images, n=1, m=1, title=''):
    
    images = images[:n*m]
    fig, axs = plt.subplots(
        nrows=n, ncols=m, 
        figsize=(15, 20), 
        subplot_kw={
            'xticks': [], 
            'yticks': []
        }
    )
    for ax, image in zip(axs.flat, images):
        ax.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.savefig(title)    
    plt.show()


def printGrafs(images, n=1, m=1, title=''):
    
    images = images[:n*m]
    fig, axs = plt.subplots(
        nrows=n, ncols=m, 
        figsize=(18, 20), 
        subplot_kw={
            'xticks': [], 
            'yticks': []
        }
    )
    for ax, image in zip(axs.flat, images):
        ax.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.savefig(title)    
    plt.show()

# %%
### DIP - VTV - GradRimm - Dirac
lsNumPrue = ['400B','390','420C','392B']
lambAsLS = ['0','0.01','0.003','0.01']
typeP = 'den25'

espColor = 'rgb'

lsData =[]
lsplotY = []

# %%
lsH = [11,20,24]
lsV = []
imgH = 11
imgV = 20

# %%
#cv2.imwrite(namefig,  imgUn)

# %%
#Recortar imagenes

def RecorImg2(rutaNameImg):

    for i in range(1,3):
        namefig = rutaNameImg + str(i) + '.png' 

        image = cv2.imread(namefig)

        imageOut = image[250:1770,220:1625]
        print(imageOut.shape)
        
        colum1=imageOut[:,:420]
        colum2=imageOut[:,480:910]
        colum3=imageOut[:,970:]
        
        imgUn=np.concatenate((colum1, colum2,colum3),axis=1)
        
        #plt.axis('off')
        #plt.imshow(imageOut)
        #plt.savefig(namefig)
        #plt.imsave(namefig,  imageOut)
        cv2.imwrite(namefig,  imgUn)

#rutaNameImg = './outGraf/' + 'grafPNSRImg'+ Nprueb +'p'
#RecorImg(rutaNameImg)

#rutaNameImg = './outGraf/'+ 'grafPNSRImgtotal'+ typeP + espColor +'p'
#RecorImg2(rutaNameImg)

# %%
#namefig = 'ComImgden25KODIMnum17' + '.png'  
namefig = 'ComImgden25KODIMnum'+ str(imgH)  + '.png'  
imgOut = cv2.imread(namefig)

# %%
plt.imshow(imgOut)

# %%
#imageREC =imgOut[300:1721,175:1360]
imageREC =imgOut[444:1575,180:1354]
print(imageREC.shape)
    
#plt.axis('off')
plt.imshow(imageREC)
# Out:
# (1131, 1174, 3)

# %%
fila1=imgOut[444:736,180:1354]
fila2=imgOut[1285:1570,180:1354]
        
imgUn=np.concatenate((fila1,fila2),axis=0)

plt.imshow(imgUn)

# %%
def RecVert1(imgOut):
    fila1=imgOut[300:880,175:1360]
    fila2=imgOut[1140:1725,175:1360]

    imgUn=np.concatenate((fila1,fila2),axis=0)

    plt.axis('off')
    plt.imshow(imgUn)
    
    return imgUn

# %%
#ls = []
num=17

for num in lsV:
    namefig = 'ComImgden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec=RecVert1(imgOut)
    namefig = 'REC/ComImgden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)

# %%
ls = []
num=17

for num in lsV:
    namefig = 'ComImgVectden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec=RecVert1(imgOut)
    namefig = 'REC/ComImgVectden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)

# %%
def RecHor1(imgOut):
    fila1=imgOut[444:736,180:1354]
    fila2=imgOut[1285:1570,180:1354]

    imgUn=np.concatenate((fila1,fila2),axis=0)

    plt.axis('off')
    plt.imshow(imgUn)
    
    return imgUn

# %%
ls = [11,20,24]
num=21

for num in lsH:
    namefig = 'ComImgden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec = RecHor1(imgOut)
    namefig = 'REC/ComImgden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)

# %%
ls = [11,20,24]
num=21

for num in lsH:
    namefig = 'ComImgVectden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec = RecHor1(imgOut)
    namefig = 'REC/ComImgVectden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)

# %%
namefig = 'ComImgRectGden25KODIMnum'+str(imgH) + '.png'  
imgOut = cv2.imread(namefig)

# %%
plt.imshow(imgOut)

# %%
imageREC = imgOut[390:1632,175:1355]
print(imageREC.shape)
    
#plt.axis('off')
plt.imshow(imageREC)
# Out:
# (1242, 1180, 3)

# %%
fila1=imgOut[390:794,175:1355]
fila2=imgOut[1224:1632,175:1355]
        
imgUn=np.concatenate((fila1,fila2),axis=0)

plt.imshow(imgUn)

# %%
def RecCuadra1(imgOut):
    fila1=imgOut[390:794,175:1355]
    fila2=imgOut[1224:1632,175:1355]

    imgUn=np.concatenate((fila1,fila2),axis=0)

    plt.axis('off')
    plt.imshow(imgUn)
    
    return imgUn

# %%
ls = [11,20,24]
num=21

for num in lsH:
    namefig = 'ComImgRectGden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec = RecCuadra1(imgOut)
    namefig = 'REC/ComImgRectGden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)
    
for num in lsH:
    namefig = 'ComImgRectRden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec = RecCuadra1(imgOut)
    namefig = 'REC/ComImgRectRden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)

# %%
namefig = 'ImgAngden25KODIMnum' + str(imgH) + '.png'  
imgOut = cv2.imread(namefig)

plt.imshow(imgOut)

# %%
imageREC = imgOut[330:1695,180:1255]
print(imageREC.shape)
    
#plt.axis('off')
plt.imshow(imageREC)
# Out:
# (1365, 1075, 3)

# %%
fila1=imgOut[330:860,180:1255]
fila2=imgOut[1165:1695,180:1255]
        
imgUn=np.concatenate((fila1,fila2),axis=0)

plt.imshow(imgUn)

print(imgUn.shape)
# Out:
# (1060, 1075, 3)

# %%
imgBarra = imgOut[480:1540,1295:1412]
print(imgBarra.shape)
    
#plt.axis('off')
plt.imshow(imgBarra)
# Out:
# (1060, 117, 3)

# %%
imgAng=np.concatenate((imgUn,imgBarra ),axis=1)

plt.imshow(imgAng)

print(imgAng.shape)
# Out:
# (1060, 1192, 3)

# %%
def RecAngV(imgOut):
    fila1=imgOut[330:860,180:1255]
    fila2=imgOut[1165:1695,180:1255]

    imgUn=np.concatenate((fila1,fila2),axis=0)

    imgBarra = imgOut[480:1540,1295:1412]
    
    imgAng=np.concatenate((imgUn,imgBarra ),axis=1)

    #plt.axis('off')
    plt.imshow(imgAng)
    
    return imgAng

# %%
ls = []
num=17

for num in lsV:
    namefig = 'ImgAngden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec =  RecAngV(imgOut)
    namefig = 'REC/ImgAngden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)

# %%
namefig = 'ImgAngden25KODIMnum' +str(imgH)+ '.png'  
imgOut = cv2.imread(namefig)

plt.imshow(imgOut)

# %%
imageREC = imgOut[455:1565,180:1250]
print(imageREC.shape)
    
#plt.axis('off')
plt.imshow(imageREC)
# Out:
# (1110, 1070, 3)

# %%
fila1=imgOut[455:725,180:1250]
fila2=imgOut[1295:1565,180:1250]
        
imgUn=np.concatenate((fila1,fila2),axis=0)

plt.imshow(imgUn)

print(imgUn.shape)
# Out:
# (540, 1070, 3)

# %%
#imgBarra = imgOut[530:1490,1295:1405] 
imgBarra = imgOut[470:1550,1295:1405] #+30+30
print(imgBarra.shape)
    
#plt.axis('off')
plt.imshow(imgBarra)
# Out:
# (1080, 110, 3)

# %%
imageDown = cv2.pyrDown(imgBarra)
print("Size of image after pyrDown: ", imageDown.shape)
plt.imshow(imageDown)
# Out:
# Size of image after pyrDown:  (540, 55, 3)

# %%
imgAng=np.concatenate((imgUn,imageDown),axis=1)

plt.imshow(imgAng)

print(imgAng.shape)
# Out:
# (540, 1125, 3)

# %%
def RecAngH(imgOut):
    fila1=imgOut[455:725,180:1250]
    fila2=imgOut[1295:1565,180:1250]

    imgUn=np.concatenate((fila1,fila2),axis=0)

    imgBarra = imgOut[470:1550,1295:1405]
    imageDown = cv2.pyrDown(imgBarra)
    
    imgAng=np.concatenate((imgUn,imageDown),axis=1)

    #plt.axis('off')
    plt.imshow(imgAng)
    
    return imgAng

# %%
ls = [11,20,24]
num= 21

for num in lsH:
    namefig = 'ImgAngden25KODIMnum' + str(num) + '.png'    

    imgOut = cv2.imread(namefig)
    imgRec =  RecAngH(imgOut)
    namefig = 'REC/ImgAngden25KODIMnum' + str(num) + 'rec.png'    
    cv2.imwrite(namefig,  imgRec)
